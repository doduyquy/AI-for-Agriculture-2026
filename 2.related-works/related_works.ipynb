# %% [markdown]
# # Related works
#
#
# > Reference: <br>
# > [[1]Data paper](../references/data_paper.pdf)<br>
# > [[2]Slide_paper_present_sample](../references/slide_paper_present_sample.pdf)<br>
# > [[3]EDA](../references/ML03_EDA.pdf)

# %% [markdown]
# <figure align="center">
#     <img src="./survey_details.png" alt="Survey details" width="700"/>
#     <figcaption>Figure 1: Survey details</figcaption>
# </figure>

# %% [markdown]
# # Read, analysis and summarize the highest scores papers in the competitive each year (total: 7, 2019-2025).

# %% [markdown]
# - Input: 7 papers
# - Output: 7 analysis, summaries and model architecture diagrams (for each paper)

# %% [markdown]
# # Baseline of competition organizers
# > Reference: [[Baseline code]](https://www.kaggle.com/competitions/beyond-visible-spectrum-ai-for-agriculture-2026/code)
# 1. Attention + fusion
# 2. ConvNeXt + fusion
#
# - Input: baseline model
# - Output: analysis, summaries and model architecture diagrams

# %% [markdown]
# ## Try another backbone models base on the baseline model.
