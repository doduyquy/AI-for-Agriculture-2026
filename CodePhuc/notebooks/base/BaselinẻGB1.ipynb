# %%
# Cell 1 — Imports + config + folder
import os
from pathlib import Path

import torch
import torch.nn as nn
import torchvision.models as models
import wandb

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
NUM_CLASSES = 3  # Health, Other, Rust

PROJECT_NAME = "beyond-visible-spectrum"
RUN_NAME = "baseline_rgb_resnet18"

# thư mục lưu checkpoint
CKPT_DIR = Path("checkpoints") / "RGB" / RUN_NAME
CKPT_DIR.mkdir(parents=True, exist_ok=True)

BEST_CKPT_PATH = CKPT_DIR / "best.pth"
LAST_CKPT_PATH = CKPT_DIR / "last.pth"

EPOCHS = 10
LR = 1e-4

# %%
# Cell 2 — Init Weights & Biases
wandb.init(
    project=PROJECT_NAME,
    name=RUN_NAME,
    config={
        "model": "resnet18",
        "input": "RGB",
        "epochs": EPOCHS,
        "batch_size": 32,  # nhớ set đúng với train_loader của bạn
        "lr": LR,
    }
)
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from C:\Users\ADMIN\_netrc.
# wandb: Currently logged in as: phucga150625 (phucga15062005) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>d:\HocTap\NCKH_ThayDoNhuTai\Challenges\Notebooks\00_baseline\wandb\run-20260127_190139-v1xecn2c</code>
# Syncing run <strong><a href='https://wandb.ai/phucga15062005/beyond-visible-spectrum/runs/v1xecn2c' target="_blank">baseline_rgb_resnet18</a></strong> to <a href='https://wandb.ai/phucga15062005/beyond-visible-spectrum' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/phucga15062005/beyond-visible-spectrum' target="_blank">https://wandb.ai/phucga15062005/beyond-visible-spectrum</a>
#  View run at <a href='https://wandb.ai/phucga15062005/beyond-visible-spectrum/runs/v1xecn2c' target="_blank">https://wandb.ai/phucga15062005/beyond-visible-spectrum/runs/v1xecn2c</a>
# &lt;wandb.sdk.wandb_run.Run object at 0x000002302C6CB5D0&gt;

# %%
# Cell 3 — Build model, loss, optimizer
model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
model.fc = nn.Linear(model.fc.in_features, NUM_CLASSES)
model = model.to(DEVICE)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LR)

# %%
# Cell 4 — 1 epoch train/val
def run_epoch(loader, train: bool):
    model.train() if train else model.eval()

    total_loss = 0.0
    correct = 0
    total = 0

    with torch.set_grad_enabled(train):
        for x, y in loader:
            x, y = x.to(DEVICE), y.to(DEVICE)

            if train:
                optimizer.zero_grad(set_to_none=True)

            logits = model(x)
            loss = criterion(logits, y)

            if train:
                loss.backward()
                optimizer.step()

            bs = x.size(0)
            total_loss += loss.item() * bs
            pred = logits.argmax(dim=1)
            correct += (pred == y).sum().item()
            total += bs

    return total_loss / max(total, 1), correct / max(total, 1)

# %%
# Cell 5 — Training loop + log + save best/last
best_val_acc = -1.0

for epoch in range(1, EPOCHS + 1):
    tr_loss, tr_acc = run_epoch(train_loader, train=True)
    va_loss, va_acc = run_epoch(val_loader, train=False)

    print(
        f"Epoch {epoch:02d} | "
        f"train loss {tr_loss:.4f} acc {tr_acc:.4f} | "
        f"val loss {va_loss:.4f} acc {va_acc:.4f}"
    )

    # log theo từng epoch (đúng vị trí)
    wandb.log(
        {
            "train_loss": tr_loss,
            "train_acc": tr_acc,
            "val_loss": va_loss,
            "val_acc": va_acc,
            "epoch": epoch,
        },
        step=epoch,
    )

    # luôn lưu last
    torch.save(
        {
            "epoch": epoch,
            "model_state_dict": model.state_dict(),
            "optimizer_state_dict": optimizer.state_dict(),
            "best_val_acc": best_val_acc,
            "config": dict(wandb.config),
        },
        LAST_CKPT_PATH,
    )

    # lưu best theo val_acc
    if va_acc > best_val_acc:
        best_val_acc = va_acc
        torch.save(
            {
                "epoch": epoch,
                "model_state_dict": model.state_dict(),
                "optimizer_state_dict": optimizer.state_dict(),
                "best_val_acc": best_val_acc,
                "config": dict(wandb.config),
            },
            BEST_CKPT_PATH,
        )
        wandb.save(str(BEST_CKPT_PATH))

# lưu last lên wandb luôn
wandb.save(str(LAST_CKPT_PATH))
# Out:
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# File c:\Users\ADMIN\.conda\envs\ocr311\Lib\site-packages\torch\utils\data\dataloader.py:1310, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1309 try:
# -> 1310     data = self._data_queue.get(timeout=timeout)
#    1311     return (True, data)
#
# File c:\Users\ADMIN\.conda\envs\ocr311\Lib\multiprocessing\queues.py:114, in Queue.get(self, block, timeout)
#     113     if not self._poll(timeout):
# --> 114         raise Empty
#     115 elif not self._poll():
#
# Empty:
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 5
#       2 best_val_acc = -1.0
#       4 for epoch in range(1, EPOCHS + 1):
# ----> 5     tr_loss, tr_acc = run_epoch(train_loader, train=True)
#       6     va_loss, va_acc = run_epoch(val_loader, train=False)
#       8     print(
#       9         f"Epoch {epoch:02d} | "
#      10         f"train loss {tr_loss:.4f} acc {tr_acc:.4f} | "
#      11         f"val loss {va_loss:.4f} acc {va_acc:.4f}"
#      12     )
#
# Cell In[6], line 10, in run_epoch(loader, train)
#       7 total = 0
#       9 with torch.set_grad_enabled(train):
# ---> 10     for x, y in loader:
#      11         x, y = x.to(DEVICE), y.to(DEVICE)
#      13         if train:
#
# File c:\Users\ADMIN\.conda\envs\ocr311\Lib\site-packages\torch\utils\data\dataloader.py:741, in _BaseDataLoaderIter.__next__(self)
#     738 if self._sampler_iter is None:
#     739     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     740     self._reset()  # type: ignore[call-arg]
# --> 741 data = self._next_data()
#     742 self._num_yielded += 1
#     743 if (
#     744     self._dataset_kind == _DatasetKind.Iterable
#     745     and self._IterableDataset_len_called is not None
#     746     and self._num_yielded > self._IterableDataset_len_called
#     747 ):
#
# File c:\Users\ADMIN\.conda\envs\ocr311\Lib\site-packages\torch\utils\data\dataloader.py:1524, in _MultiProcessingDataLoaderIter._next_data(self)
#    1520 if self._shutdown or self._tasks_outstanding <= 0:
#    1521     raise AssertionError(
#    1522         "Invalid iterator state: shutdown or no outstanding tasks when fetching next data"
#    1523     )
# -> 1524 idx, data = self._get_data()
#    1525 self._tasks_outstanding -= 1
#    1526 if self._dataset_kind == _DatasetKind.Iterable:
#    1527     # Check for _IterableDatasetStopIteration
#
# File c:\Users\ADMIN\.conda\envs\ocr311\Lib\site-packages\torch\utils\data\dataloader.py:1483, in _MultiProcessingDataLoaderIter._get_data(self)
#    1479     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1480     # need to call `.task_done()` because we don't use `.join()`.
#    1481 else:
#    1482     while True:
# -> 1483         success, data = self._try_get_data()
#    1484         if success:
#    1485             return data
#
# File c:\Users\ADMIN\.conda\envs\ocr311\Lib\site-packages\torch\utils\data\dataloader.py:1323, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1321 if len(failed_workers) > 0:
#    1322     pids_str = ", ".join(str(w.pid) for w in failed_workers)
# -> 1323     raise RuntimeError(
#    1324         f"DataLoader worker (pid(s) {pids_str}) exited unexpectedly"
#    1325     ) from e
#    1326 if isinstance(e, queue.Empty):
#    1327     return (False, None)
#
# RuntimeError: DataLoader worker (pid(s) 15616, 18572) exited unexpectedly

# %%
# Cell 6 — Finish
print("Saved:")
print(" - best:", BEST_CKPT_PATH)
print(" - last:", LAST_CKPT_PATH)
wandb.finish()
