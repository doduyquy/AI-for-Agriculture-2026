# %% [markdown]
# # Introduction

# %% [markdown]
# Tổng quan competitive: (Kaggle) AI for Agriculture 2026:
# - ...
# - ...

# %% [markdown]
# #

# %% [markdown]
# ## 1. History of challenge

# %% [markdown]
# ## 2. Competitive's problem, what is input and output:

# %% [markdown]
# ## 3. Challenges of competitive

# %% [markdown]
# ## 4. Objective of competitive
