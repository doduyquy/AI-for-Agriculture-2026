# %% [markdown]
# # Proposal methods
#
# > Reference: [Slide_paper_present_sample](../references/slide_paper_present_sample.pdf)

# %% [markdown]
# ## 1. Methods 1: ...

# %% [markdown]
# ## 2. Methods 2: ...
